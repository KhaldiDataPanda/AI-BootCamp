# %%
import pandas as pd

df = pd.read_csv(r'Data\ChicagoCrimeData.csv')
df.head(10)
# Out:
#          ID CASE_NUMBER        DATE                     BLOCK IUCR  \
# 0   3512276    HK587712  2004-08-28        047XX S KEDZIE AVE  890
# 1   3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE  820
# 2   8002131    HT233595  2011-04-04        043XX S WABASH AVE  820
# 3   7903289    HT133522  2010-12-30      083XX S KINGSTON AVE  840
# 4  10402076    HZ138551  2016-02-02           033XX W 66TH ST  820
# 5   7732712    HS540106  2010-09-29       006XX W CHICAGO AVE  810
# 6  10769475    HZ534771  2016-11-30        050XX N KEDZIE AVE  810
# 7   4494340    HL793243  2005-12-16       005XX E PERSHING RD  860
# 8   3778925    HL149610  2005-01-28     100XX S WASHTENAW AVE  810
# 9   3324217    HK361551  2004-05-13       033XX W BELMONT AVE  820
#
#   PRIMARY_TYPE                    DESCRIPTION            LOCATION_DESCRIPTION  \
# 0        THEFT                  FROM BUILDING              SMALL RETAIL STORE
# ...

# %%
df['ARREST'].value_counts()
# Out:
# ARREST
# False    370
# True     163
# Name: count, dtype: int64

# %%
df['PRIMARY_TYPE'].value_counts()
# Out:
# PRIMARY_TYPE
# THEFT                                106
# BATTERY                               92
# CRIMINAL DAMAGE                       58
# NARCOTICS                             54
# OTHER OFFENSE                         32
# ASSAULT                               32
# BURGLARY                              30
# MOTOR VEHICLE THEFT                   24
# DECEPTIVE PRACTICE                    20
# ROBBERY                               20
# CRIMINAL TRESPASS                     15
# PROSTITUTION                           6
# WEAPONS VIOLATION                      6
# PUBLIC PEACE VIOLATION                 5
# OFFENSE INVOLVING CHILDREN             4
# CRIM SEXUAL ASSAULT                    3
# SEX OFFENSE                            3
# INTERFERENCE WITH PUBLIC OFFICER       2
# GAMBLING                               2
# LIQUOR LAW VIOLATION                   2
# ARSON                                  2
# HOMICIDE                               2
# ...

# %%
primary_type_counts = df['PRIMARY_TYPE'].value_counts()

valid_types = primary_type_counts[primary_type_counts >= 4].index

print(valid_types)


df = df[ df['PRIMARY_TYPE'].isin(valid_types)]

df
# Out:
# Index(['THEFT', 'BATTERY', 'CRIMINAL DAMAGE', 'NARCOTICS', 'OTHER OFFENSE',
#        'ASSAULT', 'BURGLARY', 'MOTOR VEHICLE THEFT', 'DECEPTIVE PRACTICE',
#        'ROBBERY', 'CRIMINAL TRESPASS', 'PROSTITUTION', 'WEAPONS VIOLATION',
#        'PUBLIC PEACE VIOLATION', 'OFFENSE INVOLVING CHILDREN'],
#       dtype='object', name='PRIMARY_TYPE')
#            ID CASE_NUMBER        DATE                     BLOCK  IUCR  \
# 0     3512276    HK587712  2004-08-28        047XX S KEDZIE AVE   890
# 1     3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE   820
# 2     8002131    HT233595  2011-04-04        043XX S WABASH AVE   820
# 3     7903289    HT133522  2010-12-30      083XX S KINGSTON AVE   840
# 4    10402076    HZ138551  2016-02-02           033XX W 66TH ST   820
# ..        ...         ...         ...                       ...   ...
# 499   1806896     G635735  2001-10-22      0000X N HERMITAGE AV  2850
# 500   5766654    HN567387  2007-09-02       026XX W BELMONT AVE  1754
# ...

# %%
df.shape
# Out:
# (504, 21)

# %%
df.columns
# Out:
# Index(['ID', 'CASE_NUMBER', 'DATE', 'BLOCK', 'IUCR', 'PRIMARY_TYPE',
#        'DESCRIPTION', 'LOCATION_DESCRIPTION', 'ARREST', 'DOMESTIC', 'BEAT',
#        'DISTRICT', 'WARD', 'COMMUNITY_AREA_NUMBER', 'FBICODE', 'X_COORDINATE',
#        'Y_COORDINATE', 'YEAR', 'LATITUDE', 'LONGITUDE', 'LOCATION'],
#       dtype='object')

# %%
df['ARREST']
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 499     True
# 500    False
# 501    False
# 502     True
# 503    False
# Name: ARREST, Length: 504, dtype: bool

# %%
df['PRIMARY_TYPE']
# Out:
# 0                           THEFT
# 1                           THEFT
# 2                           THEFT
# 3                           THEFT
# 4                           THEFT
#                   ...
# 499        PUBLIC PEACE VIOLATION
# 500    OFFENSE INVOLVING CHILDREN
# 501    OFFENSE INVOLVING CHILDREN
# 502    OFFENSE INVOLVING CHILDREN
# 503    OFFENSE INVOLVING CHILDREN
# Name: PRIMARY_TYPE, Length: 504, dtype: object

# %%
list(df['PRIMARY_TYPE'].unique())
# Out:
# ['THEFT',
#  'BATTERY',
#  'CRIMINAL DAMAGE',
#  'NARCOTICS',
#  'OTHER OFFENSE',
#  'ASSAULT',
#  'BURGLARY',
#  'MOTOR VEHICLE THEFT',
#  'DECEPTIVE PRACTICE',
#  'ROBBERY',
#  'CRIMINAL TRESPASS',
#  'PROSTITUTION',
#  'WEAPONS VIOLATION',
#  'PUBLIC PEACE VIOLATION',
#  'OFFENSE INVOLVING CHILDREN']

# %%
for crime_type in df['PRIMARY_TYPE'].unique():
    
    
    df2 =  df[df['PRIMARY_TYPE'] == crime_type]
    val_cts = df2['ARREST'].value_counts()
    
    print('===',crime_type,'===')
    print(val_cts)
    
    print('\n'*2)
# Out:
# === THEFT ===
# ARREST
# False    91
# True     15
# Name: count, dtype: int64
#
#
#
# === BATTERY ===
# ARREST
# False    72
# True     20
# Name: count, dtype: int64
#
#
#
# === CRIMINAL DAMAGE ===
# ARREST
# False    52
# True      6
# Name: count, dtype: int64
#
#
#
# === NARCOTICS ===
# ARREST
# True     53
# False     1
# Name: count, dtype: int64
#
#
#
# === OTHER OFFENSE ===
# ARREST
# False    25
# True      7
# Name: count, dtype: int64
#
#
#
# === ASSAULT ===
# ARREST
# False    23
# True      9
# Name: count, dtype: int64
#
#
#
# === BURGLARY ===
# ARREST
# False    29
# True      1
# Name: count, dtype: int64
#
#
#
# === MOTOR VEHICLE THEFT ===
# ARREST
# False    23
# True      1
# Name: count, dtype: int64
#
#
#
# === DECEPTIVE PRACTICE ===
# ARREST
# False    14
# True      6
# Name: count, dtype: int64
#
#
#
# === ROBBERY ===
# ARREST
# False    17
# True      3
# Name: count, dtype: int64
#
#
#
# === CRIMINAL TRESPASS ===
# ARREST
# True     13
# False     2
# ...

# %%
df = pd.read_csv(r'Data\ChicagoCrimeData.csv')  # FROM 
df= df[df['COMMUNITY_AREA_NUMBER'] != 49] # WHERE 'COMMUNITY_AREA_NUMBER' != 49 
crime_counts = df.groupby(['PRIMARY_TYPE','ARREST','DOMESTIC']).size().reset_index(name='counts') # GROUPBY
crime_counts= crime_counts[crime_counts['PRIMARY_TYPE'] == 'THEFT'] # HAVING 'PRIMARY_TYPE' = 'THEFT'

crime_counts
# Out:
#          PRIMARY_TYPE  ARREST  DOMESTIC  counts
# 0               ARSON   False     False       2
# 1             ASSAULT   False     False      18
# 2             ASSAULT   False      True       5
# 3             ASSAULT    True     False       5
# 4             ASSAULT    True      True       4
# ..                ...     ...       ...     ...
# 59              THEFT   False     False      89
# 60              THEFT   False      True       2
# 61              THEFT    True     False      15
# 62  WEAPONS VIOLATION   False     False       1
# 63  WEAPONS VIOLATION    True     False       5
#
# [64 rows x 4 columns]
